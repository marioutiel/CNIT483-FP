# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import time

# %%
players_df = pd.read_csv('Player_URL_Stats.csv')
odds_df = pd.read_csv('NBA_Odds.csv')

local_teams = pd.read_csv('local_teams.csv')
visit_teams = pd.read_csv('visit_teams.csv')

# %%
joint = odds_df.set_index('Name').join(players_df.set_index('Name'))
joint[joint['href'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Bet, O, U, href]
# Index: []

# %%
print(f'# Rows: {joint.shape[0]}')
joint
# Out:
# # Rows: 27
#                     Bet     O     U                       href
# Name
# Aaron Gordon       23.5  −110  −120  /players/g/gordoaa01.html
# Andrew Wiggins     26.5  −105  −125  /players/w/wiggian01.html
# Anthony Davis      41.5  −115  −115  /players/d/davisan02.html
# Austin Reaves      24.5  −120  −110  /players/r/reaveau01.html
# Bam Adebayo        29.5  −135  +105  /players/a/adebaba01.html
# D'Angelo Russell   24.5  −120  −110  /players/r/russeda01.html
# Derrick White      18.5  −120  −110  /players/w/whitede01.html
# Draymond Green     22.5  −130  +100  /players/g/greendr01.html
# Gabe Vincent       19.5  −125  −105  /players/v/vincega01.html
# Jalen Brunson      34.5  −120  −110  /players/b/brunsja01.html
# Jamal Murray       34.5  −105  −125  /players/m/murraja01.html
# James Harden       37.5  −120  −110  /players/h/hardeja01.html
# Jaylen Brown       33.5  −125  −105  /players/b/brownja02.html
# Jayson Tatum       43.5  −120  −110  /players/t/tatumja01.html
# Josh Hart          23.5  −115  −115   /players/h/hartjo01.html
# Kevon Looney       22.5  −125  −105  /players/l/looneke01.html
# Klay Thompson      29.5  +100  −130  /players/t/thompkl01.html
# Kyle Lowry         18.5  −115  −115  /players/l/lowryky01.html
# LeBron James       42.5  −105  −125  /players/j/jamesle01.html
# Malcolm Brogdon    20.5  −120  −110  /players/b/brogdma01.html
# Marcus Smart       19.5  −125  −105  /players/s/smartma01.html
# Mitchell Robinson  18.5  −115  −115  /players/r/robinmi01.html
# Nikola Jokic       47.5  −120  −110  /players/j/jokicni01.html
# RJ Barrett         30.5  −110  −120  /players/b/barrerj01.html
# Stephen Curry      43.5  +100  −130  /players/c/curryst01.html
# Tobias Harris      25.5  −115  −115  /players/h/harrito02.html
# Tyrese Maxey       30.5  −110  −120  /players/m/maxeyty01.html

# %%
def get_time_sleep(idx, length):
    thr = length//10
    bounds = [thr*bound for bound in range(11)]
    
    bound = 0
    for i in range(1,len(bounds)):
        if idx in range(bounds[i-1], bounds[i]):
            bound = i
    
    return bound

# %%
def get_game_stats(game: dict) -> dict:
    local_team = local_teams[local_teams['local_team'] == game['team']].to_dict('records')[0]
    visit_team = visit_teams[visit_teams['visit_team'] == game['team_opp']].to_dict('records')[0]

    player = game | local_team | visit_team
    
    return player

# %%
def get_player_stats(idx, url):
    df = []
    
    time.sleep(get_time_sleep(idx, joint.shape[0]))
    
    req = requests.get(url)
    soup = bs(req.content, 'lxml')
    
    rows = soup.find('table', {'id': 'pgl_basic'}) \
                .find('tbody').find_all('tr')
    
    for row in rows:
        cond = row.find('td', {'data-stat': 'reason'})
        cond2 = row.find('td')
        
        if (not cond) and (cond2):
            game = {}
            
            game['date'] = row.find('td', {'data-stat': 'date_game'}) \
                              .find('a').text
            
            game['team'] = row.find('td', {'data-stat': 'team_id'}) \
                              .find('a').text
            game['team_href'] = row.find('td', {'data-stat': 'team_id'}) \
                              .find('a').get('href')
            
            game['team_opp'] = row.find('td', {'data-stat': 'opp_id'}) \
                                  .find('a').text
            game['team_opp_href'] = row.find('td', {'data-stat': 'opp_id'}) \
                                  .find('a').get('href')
            
            mp = row.find('td', {'data-stat': 'mp'}).text
            i = mp.index(':')
            game['mp'] = float(mp[:i])
            
            game['fg'] = int(row.find('td', {'data-stat': 'fg'}).text)
            
            try:
                game['fg_pct'] = float(row.find('td', {'data-stat': 'fg_pct'}).text)
            except ValueError:
                game['fg_pct'] = None
                
            game['fg3'] = int(row.find('td', {'data-stat': 'fg3'}).text)
            
            try:
                game['fg3_pct'] = float(row.find('td', {'data-stat': 'fg3_pct'}).text)
            except ValueError:
                game['fg3_pct'] = None
                
            game['ft'] = int(row.find('td', {'data-stat': 'ft'}).text)
            
            try:
                game['ft_pct'] = float(row.find('td', {'data-stat': 'ft_pct'}).text)
            except:
                game['ft_pct'] = None
                
            game['orb'] = int(row.find('td', {'data-stat': 'orb'}).text)
            game['drb'] = int(row.find('td', {'data-stat': 'drb'}).text)
            game['trb'] = int(row.find('td', {'data-stat': 'trb'}).text)
            game['ast'] = int(row.find('td', {'data-stat': 'ast'}).text)
            game['stl'] = int(row.find('td', {'data-stat': 'stl'}).text)
            game['blk'] = int(row.find('td', {'data-stat': 'blk'}).text)
            game['pts'] = int(row.find('td', {'data-stat': 'pts'}).text)
            try:
                game['+/-'] = int(row.find('td', {'data-stat': 'plus_minus'}).text)
            except ValueError:
                game['+/-'] = None
            game['pts+ast+trb'] = game['pts'] + game['trb'] + game['ast']
            
            df.append(get_game_stats(game))
            
    return pd.DataFrame(df)

# %%
players_df = []
for idx, player in enumerate(joint.index):
    print(f'{idx+1}: {player}')
    
    var_name = player.replace(' ', '_') + '_df'
    url = f'https://www.basketball-reference.com{joint["href"][idx][:-5]}/gamelog/2023'

    df = get_player_stats(idx, url)
    df['target'] = df['pts+ast+trb'].shift(-1)
    
    vars()[var_name] = df
    players_df.append(var_name)
# Out:
# 1: Aaron Gordon
# Error
# 2: Andrew Wiggins
# 3: Anthony Davis
# Error
# 4: Austin Reaves
# Error
# 5: Bam Adebayo
# 6: D'Angelo Russell
# Error
# 7: Derrick White
# 8: Draymond Green
# 9: Gabe Vincent
# 10: Jalen Brunson
# 11: Jamal Murray
# 12: James Harden
# Error
# 13: Jaylen Brown
# 14: Jayson Tatum
# 15: Josh Hart
# 16: Kevon Looney
# 17: Klay Thompson
# 18: Kyle Lowry
# 19: LeBron James
# Error
# 20: Malcolm Brogdon
# 21: Marcus Smart
# 22: Mitchell Robinson
# 23: Nikola Jokic
# 24: RJ Barrett
# 25: Stephen Curry
# 26: Tobias Harris
# 27: Tyrese Maxey
# Error

# %%
print(players_df[0])
df = vars()[players_df[0]]
df.head()
# Out:
# Aaron_Gordon_df
#          date team             team_href team_opp         team_opp_href    mp  \
# 0  2022-10-19  DEN  /teams/DEN/2023.html      UTA  /teams/UTA/2023.html  32.0
# 1  2022-10-21  DEN  /teams/DEN/2023.html      GSW  /teams/GSW/2023.html  28.0
# 2  2022-10-22  DEN  /teams/DEN/2023.html      OKC  /teams/OKC/2023.html  28.0
# 3  2022-10-24  DEN  /teams/DEN/2023.html      POR  /teams/POR/2023.html  27.0
# 4  2022-10-26  DEN  /teams/DEN/2023.html      LAL  /teams/LAL/2023.html  28.0
#
#    fg  fg_pct  fg3  fg3_pct  ...  visit_LgRank_FTr  visit_LgRank_eFG%  \
# 0  10   0.588    0    0.000  ...              14.0               15.0
# 1   5   0.417    0    0.000  ...              30.0                3.0
# 2   3   0.333    1    0.333  ...              23.0               24.0
# 3  12   0.750    0    0.000  ...               6.0               14.0
# 4   2   0.250    0    0.000  ...               2.0               18.0
#
#    visit_LgRank_TOV%  visit_LgRank_ORB%  visit_LgRank_FT/FGA  \
# 0               25.0                4.0                 14.0
# 1               30.0               14.0                 29.0
# 2                3.0               13.0                 16.0
# 3               23.0               24.0                  3.0
# 4               11.0               20.0                  2.0
#
#    visit_LgRank_opp_eFG%  visit_LgRank_opp_TOV%  visit_LgRank_DRB%  \
# 0                   13.0                   28.0               23.0
# 1                   10.0                   16.0               16.0
# 2                   19.0                    3.0               29.0
# 3                   26.0                   19.0               25.0
# 4                    7.0                   29.0               13.0
#
#    visit_LgRank_opp_FT/FGA  target
# 0                     11.0    16.0
# 1                     20.0    23.0
# 2                     24.0    33.0
# 3                     21.0    20.0
# 4                      1.0     4.0
#
# [5 rows x 84 columns]

# %%
import numpy as np
import lightgbm as lgb
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.model_selection import TimeSeriesSplit, train_test_split

# %%
def rmsle(y_true, y_pred):
    assert len(y_true) == len(y_pred)
    return np.sqrt(np.mean(np.power(np.log1p(y_true + 1) - np.log1p(y_pred + 1), 2)))

# %%
model = lgb.LGBMRegressor()
split = TimeSeriesSplit(n_splits=3)
sfs = SequentialFeatureSelector(model, n_features_to_select=20,
                               direction='forward', cv=split)

# %%
no_predictors = ['date', 'team', 'team_href', 'team_opp', 
                 'team_opp_href', 'local_team', 'visit_team', 'target']
init_predictors = df.columns[~df.columns.isin(no_predictors)]

# %%
train = pd.DataFrame()
for player in players_df:
    df = vars()[player]
    train = pd.concat([train, df])

# %%
pred = train[pd.isnull(train['target'])]
train = train[~pd.isnull(train['target'])]

# %%
nulls = pd.isnull(train[init_predictors]).sum()
nulls = nulls[nulls > 0]

valid_cols = train[init_predictors].columns[~train[init_predictors].columns.isin(nulls.index)]
to_train = train[valid_cols].copy()

# %%
sfs.fit(to_train, train['target'])
predictors = list(valid_cols[sfs.get_support()])

# %%
all_preds = []
all_errors = []
all_rmse = []
for idx, player in enumerate(players_df):
    name = player[:-3].replace('_', ' ') 
    
    df = vars()[player]
    
    to_pred = df[pd.isnull(df['target'])]
    to_train = df[~pd.isnull(df['target'])]
    
    nulls = pd.isnull(to_train[predictors]).sum()
    nulls = nulls[nulls > 0]
    
    valid_cols = to_train[predictors].columns[~to_train[predictors].columns.isin(nulls.index)]
    train = to_train[valid_cols].copy()
    
    target = to_train['target']
    X_train, X_test, y_train, y_test = train_test_split(
        train, target, test_size=0.3, shuffle=False)
    
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    
    error = rmsle(y_test, preds)
    all_errors.append(error)
    norm_error = error/(max(y_test) - min(y_test))
    print(f'Player: {name}\nRMSE = {error}\nNorm RMSLE = {norm_error}')
    all_rmse.append(norm_error)
    
    pred = model.predict(to_pred[predictors])[0]
    all_preds.append(pred)

    print('='*35)
print('\nMean RMSLE = ' + str(np.mean(all_errors)) + ' +/- ' + str(np.std(all_errors)))
print('Mean Norm RMSLE = ' + str(np.mean(all_rmse)) + ' +/- ' + str(np.std(all_rmse)))
# Out:
# Player: Aaron Gordon
# RMSE = 0.28721321302112435
# Norm RMSLE = 0.007364441359516009
# ===================================
# Player: Andrew Wiggins
# RMSE = 0.45869678644226797
# Norm RMSLE = 0.013899902619462666
# ===================================
# Player: Anthony Davis
# RMSE = 0.27365226006697707
# Norm RMSLE = 0.007818636001913631
# ===================================
# Player: Austin Reaves
# RMSE = 0.4877665516926243
# Norm RMSLE = 0.013936187191217836
# ===================================
# Player: Bam Adebayo
# RMSE = 0.42833496442149016
# Norm RMSLE = 0.01127197274793395
# ===================================
# Player: D'Angelo Russell
# RMSE = 0.37022478015034205
# Norm RMSLE = 0.010006075139198434
# ===================================
# Player: Derrick White
# RMSE = 0.41555045906981597
# Norm RMSLE = 0.011231093488373405
# ===================================
# Player: Draymond Green
# RMSE = 0.2384699124863693
# Norm RMSLE = 0.011355710118398539
# ===================================
# Player: Gabe Vincent
# RMSE = 0.5781088424689443
# Norm RMSLE = 0.023124353698757774
# ===================================
# Player: Jalen Brunson
# RMSE = 0.35531548815181696
# Norm RMSLE = 0.008075352003450385
# ===================================
# Player: Jamal Murray
# RMSE = 0.44672807188287855
# Norm RMSLE = 0.012409113107857738
# ===================================
# Player: James Harden
# RMSE = 0.26063801185022617
# Norm RMSLE = 0.006858895048690162
# ===================================
# Player: Jaylen Brown
# RMSE = 0.42564117210503366
# Norm RMSLE = 0.008867524418854867
# ===================================
# Player: Jayson Tatum
# RMSE = 0.28478786121766114
# Norm RMSLE = 0.00791077392271281
# ===================================
# Player: Josh Hart
# RMSE = 0.29977427070313717
# Norm RMSLE = 0.013626103213778962
# ===================================
# Player: Kevon Looney
# RMSE = 0.34511229258477677
# Norm RMSLE = 0.012325439020884885
# ===================================
# Player: Klay Thompson
# RMSE = 0.3435851110179782
# Norm RMSLE = 0.01227089682207065
# ===================================
# Player: Kyle Lowry
# RMSE = 0.5805012281629673
# Norm RMSLE = 0.030552696219103545
# ===================================
# Player: LeBron James
# RMSE = 0.22854030540155765
# Norm RMSLE = 0.007618010180051922
# ===================================
# Player: Malcolm Brogdon
# RMSE = 0.44272634418474016
# Norm RMSLE = 0.014281494973701295
# ===================================
# Player: Marcus Smart
# RMSE = 0.24965733472713236
# Norm RMSLE = 0.015603583420445773
# ===================================
# Player: Mitchell Robinson
# RMSE = 0.501873170292752
# Norm RMSLE = 0.02007492681171008
# ===================================
# Player: Nikola Jokic
# RMSE = 0.27388017976000323
# Norm RMSLE = 0.006680004384390322
# ===================================
# Player: RJ Barrett
# RMSE = 0.43946322078619093
# Norm RMSLE = 0.011564821599636604
# ===================================
# Player: Stephen Curry
# RMSE = 0.18567498672260668
# Norm RMSLE = 0.006189166224086889
# ===================================
# Player: Tobias Harris
# RMSE = 0.459580345524584
# Norm RMSLE = 0.01436188579764325
# ===================================
# Player: Tyrese Maxey
# RMSE = 0.35483390003039633
# Norm RMSLE = 0.009590105406226929
# ===================================
#
# Mean RMSLE = 0.3709752246269036 +/- 0.10477155437438011
# Mean Norm RMSLE = 0.01218033944222479 +/- 0.005328185821048871

# %%
joint['preds'] = all_preds
joint['norm_rmse'] = all_rmse
joint['rmse'] = all_errors
joint
# Out:
#                     Bet     O     U                       href      preds  \
# Name
# Aaron Gordon       23.5  −110  −120  /players/g/gordoaa01.html  26.762533
# Andrew Wiggins     26.5  −105  −125  /players/w/wiggian01.html  25.080000
# Anthony Davis      41.5  −115  −115  /players/d/davisan02.html  41.105263
# Austin Reaves      24.5  −120  −110  /players/r/reaveau01.html  17.266165
# Bam Adebayo        29.5  −135  +105  /players/a/adebaba01.html  35.792606
# D'Angelo Russell   24.5  −120  −110  /players/r/russeda01.html  25.639682
# Derrick White      18.5  −120  −110  /players/w/whitede01.html  16.566960
# Draymond Green     22.5  −130  +100  /players/g/greendr01.html  23.944785
# Gabe Vincent       19.5  −125  −105  /players/v/vincega01.html  11.701776
# Jalen Brunson      34.5  −120  −110  /players/b/brunsja01.html  31.559084
# Jamal Murray       34.5  −105  −125  /players/m/murraja01.html  26.609574
# James Harden       37.5  −120  −110  /players/h/hardeja01.html  38.205128
# Jaylen Brown       33.5  −125  −105  /players/b/brownja02.html  38.172756
# Jayson Tatum       43.5  −120  −110  /players/t/tatumja01.html  35.519399
# Josh Hart          23.5  −115  −115   /players/h/hartjo01.html  18.865504
# Kevon Looney       22.5  −125  −105  /players/l/looneke01.html  20.258617
# Klay Thompson      29.5  +100  −130  /players/t/thompkl01.html  30.775334
# Kyle Lowry         18.5  −115  −115  /players/l/lowryky01.html  23.027027
# LeBron James       42.5  −105  −125  /players/j/jamesle01.html  45.378378
# Malcolm Brogdon    20.5  −120  −110  /players/b/brogdma01.html  21.174145
# Marcus Smart       19.5  −125  −105  /players/s/smartma01.html  18.605648
# Mitchell Robinson  18.5  −115  −115  /players/r/robinmi01.html  21.193193
# Nikola Jokic       47.5  −120  −110  /players/j/jokicni01.html  51.635754
# RJ Barrett         30.5  −110  −120  /players/b/barrerj01.html  25.942036
# Stephen Curry      43.5  +100  −130  /players/c/curryst01.html  41.921053
# Tobias Harris      25.5  −115  −115  /players/h/harrito02.html  29.159686
# Tyrese Maxey       30.5  −110  −120  /players/m/maxeyty01.html  21.555165
#
#                    norm_rmse      rmse
# Name
# Aaron Gordon        0.007364  0.287213
# Andrew Wiggins      0.013900  0.458697
# Anthony Davis       0.007819  0.273652
# Austin Reaves       0.013936  0.487767
# Bam Adebayo         0.011272  0.428335
# D'Angelo Russell    0.010006  0.370225
# Derrick White       0.011231  0.415550
# Draymond Green      0.011356  0.238470
# Gabe Vincent        0.023124  0.578109
# Jalen Brunson       0.008075  0.355315
# Jamal Murray        0.012409  0.446728
# James Harden        0.006859  0.260638
# Jaylen Brown        0.008868  0.425641
# Jayson Tatum        0.007911  0.284788
# Josh Hart           0.013626  0.299774
# Kevon Looney        0.012325  0.345112
# Klay Thompson       0.012271  0.343585
# Kyle Lowry          0.030553  0.580501
# LeBron James        0.007618  0.228540
# Malcolm Brogdon     0.014281  0.442726
# Marcus Smart        0.015604  0.249657
# Mitchell Robinson   0.020075  0.501873
# Nikola Jokic        0.006680  0.273880
# RJ Barrett          0.011565  0.439463
# Stephen Curry       0.006189  0.185675
# Tobias Harris       0.014362  0.459580
# Tyrese Maxey        0.009590  0.354834

# %%
def american_to_decimal(player, line):
    l = player[line]
    new_l = []
    
    for num in l:
        american = int(num.replace('−', '-'))
        
        if american > 0:
            decimal = (american/100) + 1
        else:
            decimal = (100/abs(american)) + 1
         
        new_l.append(decimal)
    
    player['decimal_'+line] = new_l
    
    return player

# %%
joint_dec = american_to_decimal(joint, 'O')
joint_dec = american_to_decimal(joint_dec, 'U')

# %%
joint_dec
# Out:
#                     Bet     O     U                       href      preds  \
# Name
# Aaron Gordon       23.5  −110  −120  /players/g/gordoaa01.html  26.762533
# Andrew Wiggins     26.5  −105  −125  /players/w/wiggian01.html  25.080000
# Anthony Davis      41.5  −115  −115  /players/d/davisan02.html  41.105263
# Austin Reaves      24.5  −120  −110  /players/r/reaveau01.html  17.266165
# Bam Adebayo        29.5  −135  +105  /players/a/adebaba01.html  35.792606
# D'Angelo Russell   24.5  −120  −110  /players/r/russeda01.html  25.639682
# Derrick White      18.5  −120  −110  /players/w/whitede01.html  16.566960
# Draymond Green     22.5  −130  +100  /players/g/greendr01.html  23.944785
# Gabe Vincent       19.5  −125  −105  /players/v/vincega01.html  11.701776
# Jalen Brunson      34.5  −120  −110  /players/b/brunsja01.html  31.559084
# Jamal Murray       34.5  −105  −125  /players/m/murraja01.html  26.609574
# James Harden       37.5  −120  −110  /players/h/hardeja01.html  38.205128
# Jaylen Brown       33.5  −125  −105  /players/b/brownja02.html  38.172756
# Jayson Tatum       43.5  −120  −110  /players/t/tatumja01.html  35.519399
# Josh Hart          23.5  −115  −115   /players/h/hartjo01.html  18.865504
# Kevon Looney       22.5  −125  −105  /players/l/looneke01.html  20.258617
# Klay Thompson      29.5  +100  −130  /players/t/thompkl01.html  30.775334
# Kyle Lowry         18.5  −115  −115  /players/l/lowryky01.html  23.027027
# LeBron James       42.5  −105  −125  /players/j/jamesle01.html  45.378378
# Malcolm Brogdon    20.5  −120  −110  /players/b/brogdma01.html  21.174145
# Marcus Smart       19.5  −125  −105  /players/s/smartma01.html  18.605648
# Mitchell Robinson  18.5  −115  −115  /players/r/robinmi01.html  21.193193
# Nikola Jokic       47.5  −120  −110  /players/j/jokicni01.html  51.635754
# RJ Barrett         30.5  −110  −120  /players/b/barrerj01.html  25.942036
# Stephen Curry      43.5  +100  −130  /players/c/curryst01.html  41.921053
# Tobias Harris      25.5  −115  −115  /players/h/harrito02.html  29.159686
# Tyrese Maxey       30.5  −110  −120  /players/m/maxeyty01.html  21.555165
#
#                    norm_rmse      rmse  decimal_O  decimal_U
# Name
# Aaron Gordon        0.007364  0.287213   1.909091   1.833333
# Andrew Wiggins      0.013900  0.458697   1.952381   1.800000
# Anthony Davis       0.007819  0.273652   1.869565   1.869565
# Austin Reaves       0.013936  0.487767   1.833333   1.909091
# Bam Adebayo         0.011272  0.428335   1.740741   2.050000
# D'Angelo Russell    0.010006  0.370225   1.833333   1.909091
# Derrick White       0.011231  0.415550   1.833333   1.909091
# Draymond Green      0.011356  0.238470   1.769231   2.000000
# Gabe Vincent        0.023124  0.578109   1.800000   1.952381
# Jalen Brunson       0.008075  0.355315   1.833333   1.909091
# Jamal Murray        0.012409  0.446728   1.952381   1.800000
# James Harden        0.006859  0.260638   1.833333   1.909091
# Jaylen Brown        0.008868  0.425641   1.800000   1.952381
# Jayson Tatum        0.007911  0.284788   1.833333   1.909091
# Josh Hart           0.013626  0.299774   1.869565   1.869565
# Kevon Looney        0.012325  0.345112   1.800000   1.952381
# Klay Thompson       0.012271  0.343585   2.000000   1.769231
# Kyle Lowry          0.030553  0.580501   1.869565   1.869565
# LeBron James        0.007618  0.228540   1.952381   1.800000
# Malcolm Brogdon     0.014281  0.442726   1.833333   1.909091
# Marcus Smart        0.015604  0.249657   1.800000   1.952381
# Mitchell Robinson   0.020075  0.501873   1.869565   1.869565
# Nikola Jokic        0.006680  0.273880   1.833333   1.909091
# RJ Barrett          0.011565  0.439463   1.909091   1.833333
# Stephen Curry       0.006189  0.185675   2.000000   1.769231
# Tobias Harris       0.014362  0.459580   1.869565   1.869565
# Tyrese Maxey        0.009590  0.354834   1.909091   1.833333

# %%
def add_bet(player):
    bets = player['Bet']
    preds = player['preds']
    
    over = player['decimal_O']
    under = player['decimal_U']
    
    my_bet = []
    for idx, bet in enumerate(bets):
        if bet < preds[idx]:
            my_bet.append(over[idx])
        else:
            my_bet.append(under[idx])
            
    player['my_Bet'] = my_bet
    
    return player

# %%
final = add_bet(joint_dec)

# %%
thr = np.quantile(all_errors, .25, method='midpoint')
print(f'Threshold: {thr}')
all_errors = np.array(all_errors)
df_errors = final[['Bet', 'preds', 'my_Bet']][all_errors < thr]
print(f'# of Players: {df_errors.shape[0]}')
df_errors
# Out:
# Threshold: 0.27933402048883216
# # of Players: 7
#                  Bet      preds    my_Bet
# Name
# Anthony Davis   41.5  41.105263  1.869565
# Draymond Green  22.5  23.944785  1.769231
# James Harden    37.5  38.205128  1.833333
# LeBron James    42.5  45.378378  1.952381
# Marcus Smart    19.5  18.605648  1.952381
# Nikola Jokic    47.5  51.635754  1.833333
# Stephen Curry   43.5  41.921053  1.769231

# %%
thr = np.quantile(all_rmse, .25, method='midpoint')
print(f'Threshold: {thr}')
all_rmse = np.array(all_rmse)
df_rmse = final[['Bet', 'preds', 'my_Bet']][all_rmse < thr]
print(f'# of Players: {df_rmse.shape[0]}')
df_rmse
# Out:
# Threshold: 0.007993062963081598
# # of Players: 7
#                 Bet      preds    my_Bet
# Name
# Aaron Gordon   23.5  26.762533  1.909091
# Anthony Davis  41.5  41.105263  1.869565
# James Harden   37.5  38.205128  1.833333
# Jayson Tatum   43.5  35.519399  1.909091
# LeBron James   42.5  45.378378  1.952381
# Nikola Jokic   47.5  51.635754  1.833333
# Stephen Curry  43.5  41.921053  1.769231

# %%
in_both = []
for player in df_errors.index:
    if player in df_rmse.index:
        in_both.append(player)

# %%
print(f'# of Players: {len(in_both)}\nPlayers:')
for player in in_both:
    print(f'\t{player}')
# Out:
# # of Players: 5
# Players:
# 	Anthony Davis
# 	James Harden
# 	LeBron James
# 	Nikola Jokic
# 	Stephen Curry

# %%
data = pd.merge(df_errors, df_rmse, left_index=True, right_index=True)[['Bet_x', 'preds_x', 'my_Bet_x']]
data.rename(columns = {'Bet_x':'Bet', 'preds_x':'preds', 'my_Bet_x':'my_Bet'}, inplace = True)
data
# Out:
#                 Bet      preds    my_Bet
# Name
# Anthony Davis  41.5  41.105263  1.869565
# James Harden   37.5  38.205128  1.833333
# LeBron James   42.5  45.378378  1.952381
# Nikola Jokic   47.5  51.635754  1.833333
# Stephen Curry  43.5  41.921053  1.769231

# %%
final[final['norm_rmse'] == min(final['norm_rmse'])]
# Out:
#                 Bet     O     U                       href      preds  \
# Name
# Stephen Curry  43.5  +100  −130  /players/c/curryst01.html  41.921053
#
#                norm_rmse      rmse  decimal_O  decimal_U    my_Bet
# Name
# Stephen Curry   0.006189  0.185675        2.0   1.769231  1.769231

# %%
final[final['rmse'] == min(final['rmse'])]
# Out:
#                 Bet     O     U                       href      preds  \
# Name
# Stephen Curry  43.5  +100  −130  /players/c/curryst01.html  41.921053
#
#                norm_rmse      rmse  decimal_O  decimal_U    my_Bet
# Name
# Stephen Curry   0.006189  0.185675        2.0   1.769231  1.769231

# %%
df_rmse.to_csv('my_preds.csv')
